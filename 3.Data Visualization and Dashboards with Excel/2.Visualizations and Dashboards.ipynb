# %% [markdown]
# ### Advanced Charts

# %% [markdown]
# ![50.png](attachment:d599b23e-c095-4f98-9b74-143c879f18db.png)

# %% [markdown]
# ![51.png](attachment:d4d0e4a2-7501-4e23-b9f5-15a5021bfa80.png)
# ![52.png](attachment:61e356c4-a24f-45db-b0e2-1ed20fd5d02e.png)

# %% [markdown]
# ![53.png](attachment:7d42738c-1e6a-44a4-8527-58b713f9e416.png)

# %% [markdown]
# ![54.png](attachment:709db191-46dc-44e4-910f-df53a8c65819.png)

# %% [markdown]
# ### Creating Dashboards

# %% [markdown]
# ![55.png](attachment:7b8d97de-46bb-4380-9203-6c88e5a77bb3.png)

# %% [markdown]
# ![56.png](attachment:7ad7a595-de8f-4888-a0f1-e83b73aba194.png)

# %% [markdown]
# ![t1.png](attachment:2955e9d4-2a41-47bf-b7ec-3a1d91d6049e.png)

# %% [markdown]
# ![t2.png](attachment:e57bddec-2fb3-49ed-a7c3-c24532c969ad.png)

# %% [markdown]
# ![t3.png](attachment:e0a6c878-c762-4494-a02d-ec0f24baf668.png)
# ![t4.png](attachment:4c07ddab-2e2b-461b-9b19-e267bb44acc7.png)
