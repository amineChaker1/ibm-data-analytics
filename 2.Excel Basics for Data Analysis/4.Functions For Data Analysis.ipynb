# %% [markdown]
# ### Useful Functions

# %% [markdown]
# ![24.png](attachment:1a068d1b-5ba9-44d6-8e6a-2be567f25777.png)
# ![25.png](attachment:0ff5fa43-42be-43ce-aee3-dc6b002ccc4d.png)

# %% [markdown]
# ![29.png](attachment:5329fad8-1083-43ca-8051-e059c4f76d65.png)

# %% [markdown]
# ### V-HLOOKUP Functions

# %% [markdown]
# ![26.png](attachment:7c767d8d-d47c-4752-8234-2f5d83fe2b71.png)
# ![27.png](attachment:9f4bcffd-b520-4c7e-a91b-c139d2a40053.png)
# ![28.png](attachment:c7155c24-fdf3-487d-9812-858677da9d91.png)

# %% [markdown]
# ![30.png](attachment:43eef986-9e52-4b67-bc98-10eaa0bcb4c6.png)
