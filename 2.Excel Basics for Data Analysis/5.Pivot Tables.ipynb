# %% [markdown]
# ### Creating Pivot Tables

# %% [markdown]
# ![31.png](attachment:c55da459-5002-4ddc-9b0c-667b8b951fec.png)
# ![32.png](attachment:d4b16005-35a2-4858-a142-bf93e377ca09.png)
# ![33.png](attachment:c379a2f0-5f23-4333-b8fe-b174a189e56a.png)
# ![34.png](attachment:70da05bd-2d6e-4f0e-a439-f59fcc2eae73.png)

# %% [markdown]
# ![441.png](attachment:a37490fd-1ce2-4fb9-9e26-8137ef74748c.png)

# %% [markdown]
# ![442.png](attachment:09e1f64a-fe1c-407b-826d-b193d9432f9e.png)

# %% [markdown]
# ![443.png](attachment:e32a805b-b729-4ef3-85de-d3553e2a7bed.png)

# %% [markdown]
# ### Pivot Tables Features

# %% [markdown]
# ![35.png](attachment:b5d7f818-a3ee-49bb-a558-740744e51081.png)
# ![36.png](attachment:518ab42c-e3af-47ac-a98c-aae1ae3af6ee.png)

# %% [markdown]
# ![61.png](attachment:f6d35b3e-8f42-4660-a297-5b3b20efba8b.png)

# %% [markdown]
# ![62.png](attachment:101549b6-9ae2-417e-8c6f-98af104c5126.png)
