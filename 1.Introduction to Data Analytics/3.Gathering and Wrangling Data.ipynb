# %% [markdown]
# ### Gathering Data

# %% [markdown]
# ![1.png](attachment:68503dba-23ea-40de-9104-050087906f3a.png)

# %% [markdown]
# ![2.png](attachment:6cf3a298-3969-4b29-8a3e-34f1772b8b3a.png)
# ![3.png](attachment:0f5c7279-dc37-44fc-a8d0-44bd9035c909.png)

# %% [markdown]
# ![4.png](attachment:f75cf14d-7c66-41e1-97fb-8f88ecf96d23.png)
# ![5.png](attachment:99289530-0f1a-46f1-adac-3a9ddeb383c8.png)

# %% [markdown]
# Data sources can be internal or external to the organization, and they can be primary, secondary or third party sources of data.

# %% [markdown]
# ![6.png](attachment:b183750d-3a63-44ff-932e-3630320f54fb.png)
# ![7.png](attachment:7313c4a4-3129-4f25-a7ab-fca5dfc1711a.png)
# ![8.png](attachment:d2587733-fd45-4095-a325-5e376f6392e6.png)

# %% [markdown]
# ### Wrangling Data

# %% [markdown]
# ![9.png](attachment:f8306404-e26e-44ef-a2cf-b13be94cdee7.png)

# %% [markdown]
# ![10.png](attachment:9cb8bcfc-c908-4d44-9b57-e9242585d1fe.png)

# %% [markdown]
# ![16.png](attachment:c5c64c8b-9339-487a-8f10-fb169169d209.png)

# %% [markdown]
# ![11.png](attachment:fc459f71-9379-46ae-8294-93edb7b6170e.png)
# ![12.png](attachment:e03c1344-9288-4a2e-9d01-47c562baf46f.png)
# ![13.png](attachment:48fdb6ff-80d6-4c5e-8b13-05f6d38ee74a.png)
# ![14.png](attachment:2e56ab4a-d7b2-4ca1-9271-5b6cfc89bafe.png)

# %% [markdown]
# ![15.png](attachment:a957cf9d-372b-4ea1-bc7f-cae293b16c7b.png)
