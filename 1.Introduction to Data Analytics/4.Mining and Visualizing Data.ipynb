# %% [markdown]
# ### Statistic Analysis and Mining

# %% [markdown]
# ![1.png](attachment:ece5cf84-3682-43d0-83bc-5652f9c3c5ef.png)
# ![2.png](attachment:c1a25495-c105-41fb-bb4f-7d91e25f0a13.png)
# ![3.png](attachment:9c06e289-3004-4fe1-aa56-168d64f2b7f0.png)
# ![4.png](attachment:e64512dd-4a2e-4b07-9b99-1767b6f9c027.png)

# %% [markdown]
# ![5.png](attachment:5f82379e-40c8-42d2-b5e6-080794e13d8c.png)
# ![6.png](attachment:8eada0cd-f1a9-44f1-a7cb-ae11c5d1585a.png)

# %% [markdown]
# ![7.png](attachment:2b66d3be-86b4-4fa0-b873-9bbbbe01f2f7.png)

# %% [markdown]
# Pattern recognition is the discovery of regularity's or commonality's in data. </br>
# Consider the log data for logins to an application in an organization. It contains information such as the username, login timestamp, time spent in each login session, and activities performed. When we analyze this data to gain insights into the habits or behaviors of users, for example, the time of the day when maximum users tend to login or user roles that typically spend the maximum hours logged into the application or modules in the workflow application that are being used where examining the data manually or through tools to uncover patterns hidden in the data.
# </br>
# A trend, on the other hand, is the general tendency of a set of data to change overtime. </br>
# For example, global warming in the short term, like a year on year basis temperatures may remain the same or go up or down by a few degrees, but the overall global temperatures continue to increase overtime, making global warming a trend.

# %% [markdown]
# ![8.png](attachment:9e6d7fad-c8b5-4104-bce3-6ef9b7c59c87.png)
# ![9.png](attachment:b0bebb5c-4c13-48e8-8e8c-174d65d77dea.png)
# ![10.png](attachment:0b9d7185-8894-42ed-847f-4fca654ead51.png)

# %% [markdown]
# ### Communicating Data Analysis Findings

# %% [markdown]
# ![11.png](attachment:7575979a-5ac7-4e2f-809f-b9418000b7ed.png)

# %% [markdown]
# ![12.png](attachment:df552383-caef-4869-b7ca-71cb4adb4e6f.png)
# ![13.png](attachment:68aadaa5-debf-4551-92c9-5e521bee60fd.png)
# ![14.png](attachment:94167b3d-bd71-4ef7-90ab-08798bc08a42.png)
# ![15.png](attachment:a8d093c1-9fc7-4c98-8848-bb0eee22153b.png)
# ![16.png](attachment:4b011081-1954-4ed9-9417-f15a0b6dfd1c.png)

# %% [markdown]
# ![17.png](attachment:112876c7-e48f-44f4-9ecf-be37b3771397.png)
